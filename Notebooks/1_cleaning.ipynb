# %%
import pandas as pd
from pathlib import Path
import os

# %%
root_directory = r"data\cleaned\volley\volley"
target_order = [
    'Time', 
    'Rectus Femoris right', 'Rectus Femoris left', 
    'Hamstrings right', 'Hamstrings left', 
    'TibilaisÂ Anterior right', 'TibilaisÂ Anterior left', 
    'Gastrocnemius right', 'Gastrocnemius left'
]

# %%
df = pd.read_csv(r"data/cleaned/chipshot/jordan/1.csv", header=[3,4])
df
# Out:
#      Hamstrings right (85641)              Rectus Femoris right (85844)  \
#         EMG 1 Time Series (s)  EMG 1 (mV)         EMG 1 Time Series (s)
# 0                    0.000000   -0.205615                      0.000000
# 1                    0.000465   -0.199237                      0.000465
# 2                    0.000931   -0.170367                      0.000931
# 3                    0.001397   -0.133944                      0.001397
# 4                    0.001862   -0.101213                      0.001862
# ...                       ...         ...                           ...
# 6433                 2.994672   -0.023667                      2.994672
# 6434                 2.995138   -0.025345                      2.995138
# 6435                 2.995603   -0.025177                      2.995603
# 6436                 2.996069   -0.026184                      2.996069
# 6437                 2.996535   -0.027695                      2.996535
#
#                   Gastrocnemius left (85904)              \
#       EMG 1 (mV)       EMG 1 Time Series (s)  EMG 1 (mV)
# 0      -0.045991                    0.000000   -0.020478
# 1      -0.046494                    0.000465   -0.009232
# 2      -0.040787                    0.000931    0.001846
# 3      -0.033066                    0.001397    0.011917
# 4      -0.029374                    0.001862    0.016617
# ...          ...                         ...         ...
# 6433    0.014603                    2.994672   -0.030045
# 6434    0.012589                    2.995138   -0.032059
# 6435    0.011917                    2.995603   -0.032563
# 6436    0.014603                    2.996069   -0.031724
# 6437    0.017624                    2.996535   -0.029709
#
#      TibilaisÂ Anterior right (85650)              Hamstrings left (85586)  \
#                 EMG 1 Time Series (s)  EMG 1 (mV)    EMG 1 Time Series (s)
# 0                            0.000000    0.059587                 0.000000
# 1                            0.000465    0.042130                 0.000465
# 2                            0.000931    0.007553                 0.000931
# 3                            0.001397   -0.024338                 0.001397
# 4                            0.001862   -0.039109                 0.001862
# ...                               ...         ...                      ...
# 6433                         2.994672   -0.006882                 2.994672
# 6434                         2.995138   -0.007553                 2.995138
# 6435                         2.995603   -0.007889                 2.995603
# 6436                         2.996069   -0.006882                 2.996069
# 6437                         2.996535   -0.006043                 2.996535
#
#                  TibilaisÂ Anterior left (85605)              \
#       EMG 1 (mV)           EMG 1 Time Series (s)  EMG 1 (mV)
# 0      -0.052537                        0.000000    0.010575
# 1      -0.051530                        0.000465    0.048844
# 2      -0.051865                        0.000931    0.096178
# 3      -0.051530                        0.001397    0.150896
# 4      -0.050187                        0.001862    0.215854
# ...          ...                             ...         ...
# 6433   -0.008560                        2.994672   -0.004868
# 6434   -0.008225                        2.995138   -0.009903
# 6435   -0.006882                        2.995603   -0.013596
# 6436   -0.007217                        2.996069   -0.015106
# 6437   -0.008225                        2.996535   -0.016449
#
#       Rectus Femoris left (85878)              Gastrocnemius right (85873)  \
#             EMG 1 Time Series (s)  EMG 1 (mV)        EMG 1 Time Series (s)
# 0                        0.000000   -0.061936                     0.000000
# 1                        0.000465   -0.096849                     0.000465
# 2                        0.000931   -0.158282                     0.000931
# 3                        0.001397   -0.228107                     0.001397
# 4                        0.001862   -0.276783                     0.001862
# ...                           ...         ...                          ...
# 6433                     2.994672   -0.006882                     2.994672
# 6434                     2.995138   -0.007553                     2.995138
# 6435                     2.995603   -0.008225                     2.995603
# 6436                     2.996069   -0.010407                     2.996069
# 6437                     2.996535   -0.011582                     2.996535
#
#
#       EMG 1 (mV)
# 0      -0.000504
# 1      -0.012589
# 2      -0.030045
# 3      -0.060929
# 4      -0.087449
# ...          ...
# 6433    0.039445
# 6434    0.035752
# 6435    0.023331
# 6436    0.003861
# 6437   -0.014939
#
# [6438 rows x 16 columns]

# %%
def process_emg_file(file_path):
    try:
        # Read the file with the specific header structure
        df = pd.read_csv(file_path, header=[3, 4])
        df.dropna(axis=1)
        
        # Clean the MultiIndex columns
        df.columns = pd.MultiIndex.from_tuples(
            [(c[0].split('(')[0].strip(), c[1].strip()) for c in df.columns]
        )
        
        # Extract Time column (assuming it's the first column)
        time_col = df.iloc[:, 0]
        
        # Extract EMG data (only columns containing 'mV' in level 1)
        # We use a try/except here in case a specific file doesn't have this section
        try:
            emg_data = df.xs('EMG 1 (mV)', level=1, axis=1).copy()
        except KeyError:
            print(f"Skipping {file_path.name}: 'EMG 1 (mV)' not found.")
            return None

        # Insert Time and Reindex
        emg_data.insert(0, 'Time', time_col)
        
        # Reorder columns to match target_order
        # Note: If a file is missing one of the target columns, this will insert NaN
        emg_data = emg_data.reindex(columns=target_order)
        
        return emg_data

    except Exception as e:
        print(f"Error processing {file_path.name}: {e}")
        return None

# %%
df

# %%
processed_files = {} # Dictionary to store your results

# Path(root_directory).rglob('*.csv') searches recursively for all csv files
print(f"Searching in: {root_directory}...\n")

for file_path in Path(root_directory).rglob('*.csv'):
    print(f"Processing: {file_path}")
    
    # Apply the logic
    processed_df = process_emg_file(file_path)
    
    # Store valid results
    if processed_df is not None:
        # We use the filename (or relative path) as the key
        key_name = f"{file_path.parent.name}/{file_path.name}"
        processed_files[key_name] = processed_df

print(f"\nProcessing complete. {len(processed_files)} files successfully processed.")
# Out:
# Searching in: data\cleaned\volley\volley...
#
# Processing: data\cleaned\volley\volley\Player01\1.csv
# Processing: data\cleaned\volley\volley\Player01\2.csv
# Processing: data\cleaned\volley\volley\Player01\3.csv
# Processing: data\cleaned\volley\volley\Player01\4.csv
# Processing: data\cleaned\volley\volley\Player01\5.csv
# Processing: data\cleaned\volley\volley\Player02\1.csv
# Processing: data\cleaned\volley\volley\Player02\2.csv
# Processing: data\cleaned\volley\volley\Player02\3.csv
# Processing: data\cleaned\volley\volley\Player02\4.csv
# Processing: data\cleaned\volley\volley\Player02\5.csv
# Processing: data\cleaned\volley\volley\Player03\1.csv
# Processing: data\cleaned\volley\volley\Player03\2.csv
# Processing: data\cleaned\volley\volley\Player03\3.csv
# Processing: data\cleaned\volley\volley\Player03\4.csv
# Processing: data\cleaned\volley\volley\Player03\5.csv
# Processing: data\cleaned\volley\volley\Player04\1.csv
# Processing: data\cleaned\volley\volley\Player04\2.csv
# Processing: data\cleaned\volley\volley\Player04\3.csv
# Processing: data\cleaned\volley\volley\Player04\4.csv
# Processing: data\cleaned\volley\volley\Player04\5.csv
# Processing: data\cleaned\volley\volley\Player05\1.csv
# Processing: data\cleaned\volley\volley\Player05\2.csv
# Processing: data\cleaned\volley\volley\Player05\3.csv
# Processing: data\cleaned\volley\volley\Player05\4.csv
# Processing: data\cleaned\volley\volley\Player05\5.csv
# Processing: data\cleaned\volley\volley\Player06\1.csv
# Processing: data\cleaned\volley\volley\Player06\2.csv
# Processing: data\cleaned\volley\volley\Player06\3.csv
# Processing: data\cleaned\volley\volley\Player06\4.csv
# Processing: data\cleaned\volley\volley\Player06\5.csv
# Processing: data\cleaned\volley\volley\Player07\1.csv
# Processing: data\cleaned\volley\volley\Player07\2.csv
# Processing: data\cleaned\volley\volley\Player07\3.csv
# Processing: data\cleaned\volley\volley\Player07\4.csv
# Processing: data\cleaned\volley\volley\Player07\5.csv
# Processing: data\cleaned\volley\volley\Player08\1.csv
# Processing: data\cleaned\volley\volley\Player08\2.csv
# Processing: data\cleaned\volley\volley\Player08\3.csv
# Processing: data\cleaned\volley\volley\Player08\4.csv
# Processing: data\cleaned\volley\volley\Player08\5.csv
# Processing: data\cleaned\volley\volley\Player09\1.csv
# Processing: data\cleaned\volley\volley\Player09\2.csv
# Processing: data\cleaned\volley\volley\Player09\3.csv
# Processing: data\cleaned\volley\volley\Player09\4.csv
# Processing: data\cleaned\volley\volley\Player09\5.csv
#
# Processing complete. 45 files successfully processed.

# %%
if processed_files:
    first_key = list(processed_files.keys())[0]
    print(f"\nPreview of: {first_key}")
    display(processed_files[first_key].head())
# Out:
# Preview of: Player01/1.csv
#        Time  Rectus Femoris right  Rectus Femoris left  Hamstrings right  \
# 0  0.000000              0.062272            -0.426505         -0.029038
# 1  0.000465              0.064622            -0.677775         -0.025010
# 2  0.000931              0.065629            -0.719234         -0.018631
# 3  0.001397              0.067643            -0.598047         -0.010239
# 4  0.001862              0.070665            -0.468131         -0.001511
#
#    Hamstrings left  TibilaisÂ Anterior right  TibilaisÂ Anterior left  \
# 0        -0.277455                 -0.047166                -0.145525
# 1        -0.254963                 -0.047334                -0.162814
# 2        -0.222400                 -0.039780                -0.213672
# 3        -0.188159                 -0.024002                -0.332006
# 4        -0.169024                 -0.003861                -0.404852
#
#    Gastrocnemius right  Gastrocnemius left
# 0             0.020478            0.169360
# 1             0.019303            0.156939
# 2             0.016617            0.100374
# 3             0.013764           -0.000839
# 4             0.011246           -0.093492

# %%
output_directory = r"data\processed"

os.makedirs(output_directory, exist_ok=True)
print(f"Saving files to: {output_directory}...\n")

saved_count = 0

for key_name, df in processed_files.items():
    try:
        safe_filename = key_name.replace('\\', '_').replace('/', '_')
        save_path = os.path.join(output_directory, safe_filename)
        df.to_csv(save_path, index=False)
        
        print(f"Saved: {safe_filename}")
        saved_count += 1
        
    except Exception as e:
        print(f"Failed to save {key_name}: {e}")

print(f"\nSuccess! {saved_count} files have been saved to '{output_directory}'.")
# Out:
# Saving files to: data\processed...
#
# Saved: Player01_1.csv
# Saved: Player01_2.csv
# Saved: Player01_3.csv
# Saved: Player01_4.csv
# Saved: Player01_5.csv
# Saved: Player02_1.csv
# Saved: Player02_2.csv
# Saved: Player02_3.csv
# Saved: Player02_4.csv
# Saved: Player02_5.csv
# Saved: Player03_1.csv
# Saved: Player03_2.csv
# Saved: Player03_3.csv
# Saved: Player03_4.csv
# Saved: Player03_5.csv
# Saved: Player04_1.csv
# Saved: Player04_2.csv
# Saved: Player04_3.csv
# Saved: Player04_4.csv
# Saved: Player04_5.csv
# Saved: Player05_1.csv
# Saved: Player05_2.csv
# Saved: Player05_3.csv
# Saved: Player05_4.csv
# Saved: Player05_5.csv
# Saved: Player06_1.csv
# Saved: Player06_2.csv
# Saved: Player06_3.csv
# Saved: Player06_4.csv
# Saved: Player06_5.csv
# Saved: Player07_1.csv
# Saved: Player07_2.csv
# Saved: Player07_3.csv
# Saved: Player07_4.csv
# Saved: Player07_5.csv
# Saved: Player08_1.csv
# Saved: Player08_2.csv
# Saved: Player08_3.csv
# Saved: Player08_4.csv
# Saved: Player08_5.csv
# Saved: Player09_1.csv
# Saved: Player09_2.csv
# Saved: Player09_3.csv
# Saved: Player09_4.csv
# Saved: Player09_5.csv
#
# Success! 45 files have been saved to 'data\processed'.
