# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Laukik\\emg-gait'

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Laukik\\emg-gait'

# %%
df  = pd.read_csv(r"Datasets\Raw\ChipShot\Ahesan\1.csv")
df
# Out:
#      Hamstrings right (85641) Hamstrings right (85641).1  \
# 0             sensor mode: 40
# 1       EMG 1 Time Series (s)                 EMG 1 (mV)
# 2                         NaN               2148.1481 Hz
# 3                         NaN   0.00046551724137931035 s
# 4                           0                 -0.0310521
# ...                       ...                        ...
# 6437                2.9946724                 -0.0323949
# 6438                2.9951379                 -0.0357519
# 6439                2.9956034                 -0.0364233
# 6440                 2.996069                 -0.0350805
# 6441                2.9965345                 -0.0344091
#
#       Rectus Femoris right (85844)  Rectus Femoris right (85844).1  \
# 0                  sensor mode: 40
# 1            EMG 1 Time Series (s)                      EMG 1 (mV)
# 2                                                     2148.1481 Hz
# 3                                         0.00046551724137931035 s
# 4                                0                       0.0172885
# ...                            ...                             ...
# 6437                     2.9946724                       0.0226596
# 6438                     2.9951379                       0.0224918
# 6439                     2.9956034                       0.0213169
# 6440                      2.996069                        0.021149
# 6441                     2.9965345                       0.0219883
#
#       Gastrocnemius left (85904)  Gastrocnemius left (85904).1  \
# 0                sensor mode: 40
# 1          EMG 1 Time Series (s)                    EMG 1 (mV)
# 2                                                 2148.1481 Hz
# 3                                     0.00046551724137931035 s
# 4                              0                     0.0458228
# ...                          ...                           ...
# 6437                   2.9946724                    -0.0276951
# 6438                   2.9951379                    -0.0213169
# 6439                   2.9956034                    -0.0218204
# 6440                    2.996069                    -0.0310521
# 6441                   2.9965345                    -0.0387732
#
#      TibilaisÂ Anterior right (85650) TibilaisÂ Anterior right (85650).1  \
# 0                     sensor mode: 40
# 1               EMG 1 Time Series (s)                         EMG 1 (mV)
# 2                                                           2148.1481 Hz
# 3                                               0.00046551724137931035 s
# 4                                   0                         -0.0318914
# ...                               ...                                ...
# 6437                        2.9946724                         -0.0125887
# 6438                        2.9951379                         -0.0117494
# 6439                        2.9956034                         -0.0105745
# 6440                         2.996069                         -0.0109102
# 6441                        2.9965345                         -0.0109102
#
#       Hamstrings left (85586)  Hamstrings left (85586).1  \
# 0             sensor mode: 40
# 1       EMG 1 Time Series (s)                 EMG 1 (mV)
# 2                                           2148.1481 Hz
# 3                               0.00046551724137931035 s
# 4                           0                  0.0078889
# ...                       ...                        ...
# 6437                2.9946724                 -0.0216526
# 6438                2.9951379                 -0.0216526
# 6439                2.9956034                 -0.0206455
# 6440                 2.996069                 -0.0208133
# 6441                2.9965345                 -0.0204776
#
#      TibilaisÂ Anterior left (85605) TibilaisÂ Anterior left (85605).1  \
# 0                    sensor mode: 40
# 1              EMG 1 Time Series (s)                        EMG 1 (mV)
# 2                                                         2148.1481 Hz
# 3                                             0.00046551724137931035 s
# 4                                  0                         0.0164492
# ...                              ...                               ...
# 6437                       2.9946724                        -0.0149386
# 6438                       2.9951379                        -0.0166171
# 6439                       2.9956034                        -0.0179599
# 6440                        2.996069                        -0.0209812
# 6441                       2.9965345                        -0.0251774
#
#       Rectus Femoris left (85878)  Rectus Femoris left (85878).1  \
# 0                 sensor mode: 40
# 1           EMG 1 Time Series (s)                     EMG 1 (mV)
# 2                                                   2148.1481 Hz
# 3                                       0.00046551724137931035 s
# 4                               0                     -0.0035248
# ...                           ...                            ...
# 6437                    2.9946724                     -0.0082246
# 6438                    2.9951379                     -0.0082246
# 6439                    2.9956034                     -0.0078889
# 6440                     2.996069                     -0.0068818
# 6441                    2.9965345                     -0.0063783
#
#       Gastrocnemius right (85873)  Gastrocnemius right (85873).1
# 0                 sensor mode: 40                            NaN
# 1           EMG 1 Time Series (s)                     EMG 1 (mV)
# 2                                                   2148.1481 Hz
# 3                                       0.00046551724137931035 s
# 4                               0                     -0.0038605
# ...                           ...                            ...
# 6437                    2.9946724                     -0.0018463
# 6438                    2.9951379                     -0.0011749
# 6439                    2.9956034                     -0.0001678
# 6440                     2.996069                     -0.0008392
# 6441                    2.9965345                     -0.0025177
#
# [6442 rows x 16 columns]

# %%
df.columns
# Out:
# Index([' Hamstrings right (85641)', ' Hamstrings right (85641).1',
#        '  Rectus Femoris right (85844)', '  Rectus Femoris right (85844).1',
#        '  Gastrocnemius left (85904)', '  Gastrocnemius left (85904).1',
#        ' TibilaisÂ Anterior right (85650)',
#        ' TibilaisÂ Anterior right (85650).1', '  Hamstrings left (85586)',
#        '  Hamstrings left (85586).1', ' TibilaisÂ Anterior left (85605)',
#        ' TibilaisÂ Anterior left (85605).1', '  Rectus Femoris left (85878)',
#        '  Rectus Femoris left (85878).1', '  Gastrocnemius right (85873)',
#        '  Gastrocnemius right (85873).1'],
#       dtype='object')

# %%
def reorder_columns(df: pd.DataFrame, column_order: list) -> pd.DataFrame:
    # Ensure all provided columns exist in DataFrame
    missing_cols = [col for col in column_order if col not in df.columns]
    if missing_cols:
        raise ValueError(f"Columns not found in DataFrame: {missing_cols}")

    # Reorder columns and include any extra columns at the end
    ordered_df = df[column_order + [col for col in df.columns if col not in column_order]]
    return ordered_df

# %%
order = ['  Gastrocnemius right (85873)','  Gastrocnemius right (85873).1','  Gastrocnemius left (85904)', '  Gastrocnemius left (85904).1', '  Rectus Femoris right (85844)', '  Rectus Femoris right (85844).1', '  Rectus Femoris left (85878)','  Rectus Femoris left (85878).1',' Hamstrings right (85641)', ' Hamstrings right (85641).1','  Hamstrings left (85586)','  Hamstrings left (85586).1']

# %%
df_reordered = reorder_columns(df, order)
df_reordered
# Out:
#       Gastrocnemius right (85873)  Gastrocnemius right (85873).1  \
# 0                 sensor mode: 40                            NaN
# 1           EMG 1 Time Series (s)                     EMG 1 (mV)
# 2                                                   2148.1481 Hz
# 3                                       0.00046551724137931035 s
# 4                               0                     -0.0038605
# ...                           ...                            ...
# 6437                    2.9946724                     -0.0018463
# 6438                    2.9951379                     -0.0011749
# 6439                    2.9956034                     -0.0001678
# 6440                     2.996069                     -0.0008392
# 6441                    2.9965345                     -0.0025177
#
#       Gastrocnemius left (85904)  Gastrocnemius left (85904).1  \
# 0                sensor mode: 40
# 1          EMG 1 Time Series (s)                    EMG 1 (mV)
# 2                                                 2148.1481 Hz
# 3                                     0.00046551724137931035 s
# 4                              0                     0.0458228
# ...                          ...                           ...
# 6437                   2.9946724                    -0.0276951
# 6438                   2.9951379                    -0.0213169
# 6439                   2.9956034                    -0.0218204
# 6440                    2.996069                    -0.0310521
# 6441                   2.9965345                    -0.0387732
#
#       Rectus Femoris right (85844)  Rectus Femoris right (85844).1  \
# 0                  sensor mode: 40
# 1            EMG 1 Time Series (s)                      EMG 1 (mV)
# 2                                                     2148.1481 Hz
# 3                                         0.00046551724137931035 s
# 4                                0                       0.0172885
# ...                            ...                             ...
# 6437                     2.9946724                       0.0226596
# 6438                     2.9951379                       0.0224918
# 6439                     2.9956034                       0.0213169
# 6440                      2.996069                        0.021149
# 6441                     2.9965345                       0.0219883
#
#       Rectus Femoris left (85878)  Rectus Femoris left (85878).1  \
# 0                 sensor mode: 40
# 1           EMG 1 Time Series (s)                     EMG 1 (mV)
# 2                                                   2148.1481 Hz
# 3                                       0.00046551724137931035 s
# 4                               0                     -0.0035248
# ...                           ...                            ...
# 6437                    2.9946724                     -0.0082246
# 6438                    2.9951379                     -0.0082246
# 6439                    2.9956034                     -0.0078889
# 6440                     2.996069                     -0.0068818
# 6441                    2.9965345                     -0.0063783
#
#      Hamstrings right (85641) Hamstrings right (85641).1  \
# 0             sensor mode: 40
# 1       EMG 1 Time Series (s)                 EMG 1 (mV)
# 2                         NaN               2148.1481 Hz
# 3                         NaN   0.00046551724137931035 s
# 4                           0                 -0.0310521
# ...                       ...                        ...
# 6437                2.9946724                 -0.0323949
# 6438                2.9951379                 -0.0357519
# 6439                2.9956034                 -0.0364233
# 6440                 2.996069                 -0.0350805
# 6441                2.9965345                 -0.0344091
#
#       Hamstrings left (85586)  Hamstrings left (85586).1  \
# 0             sensor mode: 40
# 1       EMG 1 Time Series (s)                 EMG 1 (mV)
# 2                                           2148.1481 Hz
# 3                               0.00046551724137931035 s
# 4                           0                  0.0078889
# ...                       ...                        ...
# 6437                2.9946724                 -0.0216526
# 6438                2.9951379                 -0.0216526
# 6439                2.9956034                 -0.0206455
# 6440                 2.996069                 -0.0208133
# 6441                2.9965345                 -0.0204776
#
#      TibilaisÂ Anterior right (85650) TibilaisÂ Anterior right (85650).1  \
# 0                     sensor mode: 40
# 1               EMG 1 Time Series (s)                         EMG 1 (mV)
# 2                                                           2148.1481 Hz
# 3                                               0.00046551724137931035 s
# 4                                   0                         -0.0318914
# ...                               ...                                ...
# 6437                        2.9946724                         -0.0125887
# 6438                        2.9951379                         -0.0117494
# 6439                        2.9956034                         -0.0105745
# 6440                         2.996069                         -0.0109102
# 6441                        2.9965345                         -0.0109102
#
#      TibilaisÂ Anterior left (85605) TibilaisÂ Anterior left (85605).1
# 0                    sensor mode: 40
# 1              EMG 1 Time Series (s)                        EMG 1 (mV)
# 2                                                         2148.1481 Hz
# 3                                             0.00046551724137931035 s
# 4                                  0                         0.0164492
# ...                              ...                               ...
# 6437                       2.9946724                        -0.0149386
# 6438                       2.9951379                        -0.0166171
# 6439                       2.9956034                        -0.0179599
# 6440                        2.996069                        -0.0209812
# 6441                       2.9965345                        -0.0251774
#
# [6442 rows x 16 columns]

# %%
santacruz_new_columns["FFF"] = pd.to_numeric(santacruz_new_columns["FFF"], errors="coerce")
santacruz_new_columns["DD"] = pd.to_numeric(santacruz_new_columns["DD"], errors="coerce")

# %%
santacruz_new_columns.isnull().sum()

# %%
santacruz_cleaned = santacruz_new_columns.interpolate()
santacruz_cleaned.isnull().sum()

# %%
normals = {
    1: 30.4, 2: 31.1, 3: 32.6, 4: 33.0, 5: 33.3, 6: 32.0,
    7: 29.9, 8: 29.5, 9: 30.2, 10: 33.1, 11: 33.4, 12: 31.9
}
santacruz_cleaned.insert(loc=8, column='Normal_Temp', value=santacruz_cleaned['MN'].map(normals))

# %%
santacruz_cleaned

# %%
df = pd.read_csv(r"notebook\data\combined_data.csv")

# %%
df

# %%
df.drop(columns=['SLP','RH','DD','FFF','RF'],inplace=True)

# %%
df

# %%
normals = {
    1: 30.4, 2: 31.1, 3: 32.6, 4: 33.0, 5: 33.3, 6: 32.0,
    7: 29.9, 8: 29.5, 9: 30.2, 10: 33.1, 11: 33.4, 12: 31.9
}
df.insert(loc=7, column='Normal_Temp', value=df['MN'].map(normals))

# %%
df.isnull().sum()

# %%
df=df.interpolate()

# %%
if os.path.exists(r"notebook\data\santacruz_combined_normal.csv"):
    print("Labelled processed data exists")
else:
    df.to_csv(r"notebook\data\santacruz_combined_normal.csv", index=False)
    print("Labelled processed data created")

# %%
df['DATE'] = pd.to_datetime(df[['YEAR', 'MN', 'DT']].rename(columns={'MN': 'month', 'DT': 'day'}))
df.set_index('DATE', inplace=True)
df

# %%
df.drop(columns=['YEAR', 'MN', 'DT', 'HR'], inplace=True)

# %%
daily_df = df.resample('D').mean()

# %%
daily_df

# %%
daily_df.isnull().sum()

# %%
daily_df = daily_df.interpolate()
daily_df.isnull().sum()

# %%
if os.path.exists(r"notebook\data\unpred\santacruz_daily.csv"):
    print("Labelled processed data exists")
else:
    daily_df.to_csv(r"notebook\data\unpred\santacruz_daily.csv")
    print("Labelled processed data created")
